# %%
# import required libraries
from kafka import KafkaConsumer

# %%
# Connect to kafka broker running in your local host (docker). Change this to your kafka broker if needed
kafka_broker = 'localhost:9092'

# %%
consumer = KafkaConsumer(
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: x.decode('utf-8'))

# %%
consumer.subscribe(['sample'])

# %%
print('Running Consumer #2')
while(True):
    results = consumer.poll(timeout_ms=1000)
    if len(results) == 0:
        print('no message')
    else:
        for tp, messages in results.items():
            print('topic = {} -- total {} messages'.format(tp.topic, len(messages)))
            print('-----')
            for message in messages:
                print(message)
    print('######################')
# Out:
# Running Consumer #2
# topic = sample -- total 6 messages
# -----
# ConsumerRecord(topic='sample', partition=0, leader_epoch=0, offset=140, timestamp=1762239096129, timestamp_type=0, key=None, value='message #74 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ConsumerRecord(topic='sample', partition=0, leader_epoch=0, offset=141, timestamp=1762239097315, timestamp_type=0, key=None, value='message #44 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ConsumerRecord(topic='sample', partition=0, leader_epoch=0, offset=142, timestamp=1762239098132, timestamp_type=0, key=None, value='message #75 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ConsumerRecord(topic='sample', partition=0, leader_epoch=0, offset=143, timestamp=1762239100137, timestamp_type=0, key=None, value='message #76 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ConsumerRecord(topic='sample', partition=0, leader_epoch=0, offset=144, timestamp=1762239100318, timestamp_type=0, key=None, value='message #45 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ConsumerRecord(topic='sample', partition=0, leader_epoch=0, offset=145, timestamp=1762239102140, timestamp_type=0, key=None, value='message #77 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# no message
# ######################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 print('Running Consumer #2')
#       2 while(True):
# ----> 3     results = consumer.poll(timeout_ms=1000)
#       4     if len(results) == 0:
#       5         print('no message')
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Classes/Data Science and Data Engineering/Examples/data-ingestion/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Classes/Data Science and Data Engineering/Examples/data-ingestion/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Classes/Data Science and Data Engineering/Examples/data-ingestion/.venv/lib/python3.9/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Classes/Data Science and Data Engineering/Examples/data-ingestion/.venv/lib/python3.9/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:
