# %% [markdown]
# # Data Extraction with Selenium
# In this tutorial, we discuss how to use Selenium to extract data from the web.  Please see https://selenium-python.readthedocs.io for more details.

# %% [markdown]
# ## Installation
# Before using selenium, we will have to install a webdriver of your choice.  It can be Chrome or Firefox.  Once installed, you will need to know the location of the drive as it will be used as a parameter to start a browser.  To install the driver, just install python helper package chromedriver_autoinstaller.
#
#         pip install chromedriver_autoinstaller
#
# We also have to install selenium package.
#
#         pip install selenium

# %%
from selenium import webdriver
import chromedriver_autoinstaller
import time
import os
# Out:
# /Users/natawut/Library/Mobile Documents/com~apple~CloudDocs/Classes/Data Science and Data Engineering/Examples/data-extraction-examples/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
chromedriver_autoinstaller.install()
# Out:
# CHROME >= 115, using mac-arm64 as architecture identifier
# '/Users/natawut/Library/Mobile Documents/com~apple~CloudDocs/Classes/Data Science and Data Engineering/Examples/data-extraction-examples/.venv/lib/python3.9/site-packages/chromedriver_autoinstaller/141/chromedriver'

# %%
browser = webdriver.Chrome()

# %% [markdown]
# ## Browsing a webpage
# Once the browser starts, we can tell it to visit a webpage.

# %%
url = 'https://www.google.com'

# %%
browser.get(url=url)

# %%
html = browser.execute_script("return document.documentElement.outerHTML")
html[:3000]
# Out:
# '<html itemscope="" itemtype="http://schema.org/WebPage" lang="th"><head><meta charset="UTF-8"><meta content="dark light" name="color-scheme"><meta content="origin" name="referrer"><link href="//www.gstatic.com/images/branding/searchlogo/ico/favicon.ico" rel="icon"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="">window._hst=Date.now();</script><script nonce="">(function(){var _g={kEI:\'RXP_aKln4_zV7w_J5fOICA\',kEXPI:\'31\',kBL:\'KYuT\',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'webhp\';google.kHL=\'th\';google.rdn=false;})();(function(){\nvar g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction r(a,b,d,c,h){var e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);(function(){google.y={};google.sy={};function e(a,b,c){if(a)var d=a.id;else{do d=Math.random();while(c[d])}c[d]=[a,b]}var f;(f=google).x||(f.x=function(a,b){e(a,b,google.y)});var g;(g=google).sx||(g.sx=function(a,b){e(a,b,google.sy)});google.lm=[];var h;(h=google).plm||(h.plm=function(a){google.lm.push.apply(google.lm,a)});google.lq=[];var k;(k=google).load||(k.load=function(a,b,c){google.lq.push([[a],b,c])});var l;(l=google).loadAll||(l.loadAll=function(a,b){google.lq.push([a,b])});google.bx=!1;var m;(m=google).lx||(m.lx=function(){});var n=[],p;(p=google).fce||(p.fce=function(a,b,c,d){n.push([a,b,c,d])});google.qce=n;google.adl=[];}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){google.hs={h:true,nhs:fal'

# %% [markdown]
# ## Interact with a webpage
# When the page is loaded, we can interact with all elements in the webpage.  In this example, we will perform a search for a particular keyword in Google.  We will have to locate the correct element and then send the proper keys.

# %%
from selenium.webdriver.common.by import By

# %%
q_element = browser.find_element(By.CSS_SELECTOR, '[name=q]')

# %%
q_element.clear()
q_element.send_keys('ประเทศไทย')
q_element.send_keys(u'\ue007')

# %% [markdown]
# ## Navigate the webpage
# We can navigate the current webpage, similar to Beautiful Soup.  Selenium supports several navigation approaches.

# %%
all_link = browser.find_elements(By.CSS_SELECTOR, '#search a[jsname]')

# %%
for link in all_link:
    print('[link text]', link.text)
    print('[link href]', link.get_attribute('href'))
    print('---')
# Out:
# [link text] ประเทศไทย
# Wikipedia
# https://th.wikipedia.org › wiki › ประเทศไทย
# [link href] https://th.wikipedia.org/wiki/%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9
# ---
# [link text] ภูมิศาสตร์ไทย
# Wikipedia
# https://th.wikipedia.org › wiki › ภูมิศาสตร์ไทย
# [link href] https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B9%E0%B8%A1%E0%B8%B4%E0%B8%A8%E0%B8%B2%E0%B8%AA%E0%B8%95%E0%B8%A3%E0%B9%8C%E0%B9%84%E0%B8%97%E0%B8%A2
# ---
# [link text] เกี่ยวกับประเทศไทย
# WHA Industrial Development
# https://www.wha-industrialestate.com › about-thailand
# [link href] https://www.wha-industrialestate.com/th/why-thailand/about-thailand
# ---
# [link text] ประเทศไทย
# World Bank Open Data
# https://data.worldbank.org › country › thailand
# [link href] https://data.worldbank.org/country/thailand?locale=th
# ---
# [link text] 8 เรื่องของประเทศไทย ที่คุณอาจไม่เคยรู้ l #สาระศาสตร์
# YouTube · ช่อง8 : Thai Ch8
# ยอดดูกว่า 844.4K ครั้ง · 2 เดือนที่ผ่านมา
# [link href] https://www.youtube.com/shorts/o6FXDQhA76w
# ---
# [link text] ประวัติประเทศไทย
# NECTEC
# https://www.nectec.or.th › library › create-web › history
# [link href] https://www.nectec.or.th/schoolnet/library/create-web/10000/history/10000-8041.html
# ---
# [link text] ประเทศไทย - BBC News ไทย
# BBC
# https://www.bbc.com › thai › topics
# [link href] https://www.bbc.com/thai/topics/cjgn73g98rqt
# ---
# [link text] ข้อมูลพื้นฐานประเทศไทย
# กรมสนับสนุนบริการสุขภาพ
# https://hss.moph.go.th › fileupload_doc_slider
# [link href] https://hss.moph.go.th/fileupload_doc_slider/2016-12-13--501.pdf
# ---

# %%
all_link[0].click()

# %%
all_headlines = browser.find_elements(By.CSS_SELECTOR, '.vector-toc-text span:not([class]')

# %%
for h in all_headlines:
    print('[text]', h.text)
    print('[tag]', h.tag_name)
    parent = h.find_element(By.XPATH, '..')
    print('[parent / class] {} / {}'.format(parent.tag_name, parent.get_attribute('class')))
    print('---')
# Out:
# [text] ชื่อเรียก
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] ประวัติศาสตร์
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] ภูมิประเทศ
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] การเมืองการปกครอง
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] เศรษฐกิจ
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] ประชากรศาสตร์
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] วัฒนธรรม
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] เชิงอรรถ
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] อ้างอิง
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] อ่านเพิ่ม
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] แหล่งข้อมูลอื่น
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text] โครงสร้างพื้นฐาน
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---
# [text]
# [tag] span
# [parent / class] div / vector-toc-text
# ---

# %% [markdown]
# ## End browsing session

# %%
browser.quit()
